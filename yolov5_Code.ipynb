# %% [markdown]
# ## Connecting with drive and some operating system steps for path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path='/content/drive/MyDrive/tbx11k-simplified'
print(os.listdir(path))
# Out:
# ['data.csv', 'images', 'test', 'Dataset', 'yolov5', 'accuracyplot.png', 'lossplot.png', 'CM.png', 'TB_416x416', 'Yolo_data', 'VIT.ipynb']

# %%
os.chdir('/content/drive/MyDrive/tbx11k-simplified')

# %% [markdown]
# ## Cloning yolov5 Model

# %%
# #clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo

# %%
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow
# Out:
# /content/drive/MyDrive/tbx11k-simplified/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 KB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 6.4 MB/s eta 0:00:00
# ...

# %%
import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.0.0+cu118 (Tesla T4)

# %%
# !ls
# Out:
# benchmarks.py	 detect.py   __pycache__       segment	       val.py
# CITATION.cff	 export.py   README.md	       setup.cfg       yolov5s.pt
# classify	 hubconf.py  README.zh-CN.md   train.py
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data		 models      runs	       utils

# %%
import os
os.chdir('/content/drive/MyDrive/tbx11k-simplified/yolov5')

# %%
# !ls
# Out:
# benchmarks.py	 detect.py   __pycache__       segment	       val.py
# CITATION.cff	 export.py   README.md	       setup.cfg       yolov5s.pt
# classify	 hubconf.py  README.zh-CN.md   train.py
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data		 models      runs	       utils

# %% [markdown]
# ## Training the Model

# %%
# !python train.py --img 256 --batch 16 --epochs 150 --data data/custom_model.yaml --weights yolov5s.pt --cache
# Out:
# 2023-04-06 08:50:33.544595: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-06 08:50:34.563916: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
sssssssss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6832a693c5ca> in <cell line: 1>()
# ----> 1 sssssssss
#
# NameError: name 'sssssssss' is not defined

# %%
# !python train.py --img 256 --batch 16 --epochs 150 --data data/new_custom.yaml --weights runs/train/exp/weights/best.pt --cache

# %% [markdown]
# ## Testing the Model

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 256 --conf 0.3 --source /content/drive/MyDrive/tbx11k-simplified/Dataset/New_TB/test
